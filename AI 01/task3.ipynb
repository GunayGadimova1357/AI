# %%
import numpy as np
from IPython.display import Markdown, display

# %%
sales = [120, 135, 100, 150, 90, 200, 170]

# %%
total_sales = np.sum(sales)
average_sales = np.mean(sales)
max_sales = np.max(sales)
min_sales = np.min(sales)

# %%
display(Markdown(f""" # **Sales Report:**
| Metric | Value |
|---|---|
| Total Sales | {total_sales} |
| Average | {average_sales:.2f} |
| Maximum | {max_sales} |
| Minimum | {min_sales} | """ ))
# Out:
#  # **Sales Report:**
# | Metric | Value |
# |---|---|
# | Total Sales | 965 |
# | Average | 137.86 |
# | Maximum | 200 |
# | Minimum | 90 |
